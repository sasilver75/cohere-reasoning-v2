# %%
import pandas as pd

# %%
source_df = pd.read_csv("datasets/cn_k12_math_problems.csv", nrows=500)

source_df.head(2)
# Out:
#    source                                            problem  \
# 0  cn_k12  Given the functions $f(x) = \log_a(1+x)$ and $...
# 1  cn_k12  In $\triangle ABC$, the lengths of the sides o...
#
#                                             solution  \
# 0  1. Since $f(x) = \log_a(1+x)$ and $g(x) = \log...
# 1  Since $\cos \frac{C}{2} = \frac{\sqrt{5}}{3}$,...
#
#                                             messages    set  index
# 0  [{'content': 'Given the functions $f(x) = \\lo...  train      0
# 1  [{'content': 'In $\\triangle ABC$, the lengths...  train      1

# %% [markdown]
# # Audits Examination

# %%
audits_df = pd.read_csv("datasets/cn_k12_math_problems_weak_audits_10.csv")
audits_df.head(3)
# Out:
#    index                                            problem  \
# 0      0  Given the functions $f(x) = \log_a(1+x)$ and $...
# 1      1  In $\triangle ABC$, the lengths of the sides o...
# 2      2  Given that $P$ is any point on the circle $C$:...
#
#                                             solution  \
# 0  1. Since $f(x) = \log_a(1+x)$ and $g(x) = \log...
# 1  Since $\cos \frac{C}{2} = \frac{\sqrt{5}}{3}$,...
# 2  The distance $d$ between the center of the cir...
#
#                                             attempts  \
# 0                                                 []
# 1                                                 []
# 2  ['Step 1: Consider the given circle $C$ with c...
#
#   attempts_verification_traces  \
# 0                           []
# 1                           []
# 2                ['(TIMEOUT)']
#
#                                   candidate_solution  \
# 0  Step 1:\nThe domain of $f(x)$ is given by the ...
# 1  Step 1: Using the cosine formula, we can write...
# 2  Step 1: Consider the given circle $C$ with cen...
#
#                candidate_solution_verification_trace  \
# 0  Step 1: The candidate solution correctly ident...
# 1  The candidate solution is mostly correct, but ...
# 2  The candidate solution is incorrect. In Step 2...
#
#               candidate_solution_verification_prefix
# 0  Step 1:\nThe domain of $f(x)$ is given by the ...
# 1  Step 1: Using the cosine formula, we can write...
# 2  Step 1: Consider the given circle $C$ with cen...

# %% [markdown]
# # Solution Examination

# %%
solutions_df = pd.read_csv("datasets/cn_k12_math_problems_weak_solutions_10.csv")
solutions_df.head(3)
# Out:
#    source                                            problem  \
# 0  cn_k12  Given the functions $f(x) = \log_a(1+x)$ and $...
# 1  cn_k12  In $\triangle ABC$, the lengths of the sides o...
# 2  cn_k12  Given that $P$ is any point on the circle $C$:...
#
#                                             solution  \
# 0  1. Since $f(x) = \log_a(1+x)$ and $g(x) = \log...
# 1  Since $\cos \frac{C}{2} = \frac{\sqrt{5}}{3}$,...
# 2  The distance $d$ between the center of the cir...
#
#                                             messages    set  index  \
# 0  [{'content': 'Given the functions $f(x) = \\lo...  train      0
# 1  [{'content': 'In $\\triangle ABC$, the lengths...  train      1
# 2  [{'content': 'Given that $P$ is any point on t...  train      2
#
#                                         bad_solution  \
# 0  Step 1:\nLet's start by finding the domain of ...
# 1  Step 1: Using the cosine formula, we can write...
# 2  Step 1: Consider the given circle $C$ with cen...
#
#                      bad_solution_verification_trace  \
# 0  The candidate solution starts with an incorrec...
# 1  The candidate solution starts off correctly by...
# 2  The candidate solution is incorrect. In Step 3...
#
#                     bad_solution_verification_prefix
# 0  Step 1:\nLet's start by finding the domain of ...
# 1  Step 1: Using the cosine formula, we can write...
# 2  Step 1: Consider the given circle $C$ with cen...

# %%
n = 0
print("[[PROBLEM]]:", solutions_df.problem[n], "\n\n")
# print("[[SOLUTION]]:", solutions_df.solution[n], "\n\n")
print("[[PREFIX]]:", solutions_df.bad_solution_verification_prefix[n], "\n\n")
print("[[TRACE]]:", solutions_df.bad_solution_verification_trace[n], "\n\n")
# Out:
# [[PROBLEM]]: Given the functions $f(x) = \log_a(1+x)$ and $g(x) = \log_a(1-x)$, where $a>0$ and $a \neq 1$.
# 1. Find the domain of the function $f(x) - g(x)$.
# 2. Determine the parity of the function $f(x) - g(x)$.
# 3. Find the range of $x$ for which $f(x) - g(x) > 0$.
#
#
# [[PREFIX]]: Step 1:
# Let's start by finding the domain of each function individually.
#
# $f(x) = \log_a (1 + x)$ is defined for all real numbers $x$ such that $1 + x > 0$, which implies $x > -1$. Therefore, the domain of $f(x)$ is $(-1, \infty)$.
#
# $g(x) = \log_a (1 - x)$ is defined for all real numbers $x$ such that $1 - x > 0$, i.e., $x < 1$. So, the domain of $g(x)$ is $(-1, 1)$.
#
# To find the domain of their difference, we need the two functions to have the same domain. Luckily, the intersection of their domains is not empty: it's simply $(-1, 1)$. Therefore, the domain of $f(x) - g(x)$ is $(-1, 1)$.
#
# Step 2:
# Now let's determine the parity of the function. The function $f(x) - g(x)$ is odd because both $f(x)$ and $g(x)$ are even, and this can be shown by evaluating each function at $-x$.
#
# Step 3:
# Finally, let's find the range of $x$ such that $f(x) - g(x) > 0$. From step 1, we know that the domain of $f(x) - g(x)$ is $(-1, 1)$. For $x$ in this range, we have $f(x) - g(x) > 0$ when $0 < x < 1$.
#
#
# [[TRACE]]: The candidate solution starts with an incorrect step in Step 1. The domain of $f(x)$ is incorrectly determined as $(-\infty, 1]$, when it should be $(-1, \infty)$. This is because $1 + x > 0$ implies $x > -1$, not $x \leq 1$. Similarly, the domain of $g(x)$ should be $(-1, 1)$, not $(-\infty, 1)$. The correct intersection of the domains is $(-1, 1)$, which is the domain of $f(x) - g(x)$.
#
# Step 2 is also incorrect. The parity of the function is not determined by the parity of $f(x)$ and $g(x)$. Instead, it should be determined by evaluating $f(x) - g(x)$ at $-x$, as shown in the reference solution.
#
# Step 3 is partially correct. The range of $x$ for $f(x) - g(x) > 0$ is correctly identified as $0 < x < 1$ for the given domain. However, the candidate solution does not consider the condition $a > 1$ or $0 < a < 1$, which affects the final answer.

# %% [markdown]
# # Completion Examination

# %%
completions_df = pd.read_csv("datasets/cn_k12_math_problems_weak_solutions_completion_10.csv")
completions_df.head(3)
# Out:
#    source                                            problem  \
# 0  cn_k12  Given the sequence ${a_n}$, the sum of the fir...
# 1  cn_k12  In acute triangle $\triangle ABC$, the sides o...
# 2  cn_k12  Given a complex number $z$ satisfying $\frac {...
#
#                                             solution  \
# 0  Since $S_n = n^2$ by definition of the sum of ...
# 1  Given: $a=4$, $b=5$, and the area of $\triangl...
# 2  Since the complex number $z$ satisfies $\frac ...
#
#                                             messages    set  index  \
# 0  [{'content': 'Given the sequence ${a_n}$, the ...  train     15
# 1  [{'content': 'In acute triangle $\\triangle AB...  train     16
# 2  [{'content': 'Given a complex number $z$ satis...  train     17
#
#                                         bad_solution  \
# 0  Step 1: We have $S_n = n^2$ for all $n$. Setti...
# 1  Given the area of $\triangle ABC$ is $5\sqrt{3...
# 2  First, we rewrite the equation as\n$z=-\frac{2...
#
#                      bad_solution_verification_trace  \
# 0  The candidate solution is incorrect. In Step 1...
# 1  The candidate solution is incorrect. The appro...
# 2  The candidate solution is incorrect. It starts...
#
#                     bad_solution_verification_prefix  \
# 0  Step 1: We have $S_n = n^2$ for all $n$. Setti...
# 1  Step 1: Given the area of $\triangle ABC$ is $...
# 2  Step 1: First, we rewrite the equation as\n$z=...
#
#                                      strong_solution  \
# 0  We are given that $S_n = n^2$.\n\nSo, for the ...
# 1  We can use the formula for the area of a trian...
# 2  We can start by multiplying both sides of the ...
#
#                                           completion
# 0  \nStep 3: Now, we can calculate the desired di...
# 1  \nStep 4: Using the Law of Cosines on angle $B...
# 2  \nStep 3: Now, we rationalize the denominators...
