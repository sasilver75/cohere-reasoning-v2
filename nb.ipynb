# %%
import pandas as pd

# %%
source_df = pd.read_csv("datasets/cn_k12_math_problems.csv", nrows=500)

source_df.head(2)
# Out:
#    source                                            problem  \
# 0  cn_k12  Given the functions $f(x) = \log_a(1+x)$ and $...
# 1  cn_k12  In $\triangle ABC$, the lengths of the sides o...
#
#                                             solution  \
# 0  1. Since $f(x) = \log_a(1+x)$ and $g(x) = \log...
# 1  Since $\cos \frac{C}{2} = \frac{\sqrt{5}}{3}$,...
#
#                                             messages    set  index
# 0  [{'content': 'Given the functions $f(x) = \\lo...  train      0
# 1  [{'content': 'In $\\triangle ABC$, the lengths...  train      1

# %% [markdown]
# # Result examination

# %%
df = pd.read_csv("datasets/cn_k12_math_problems_weak_solutions_5.csv")
df.head()
# Out:
#    source                                            problem  \
# 0  cn_k12  Given the functions $f(x) = \log_a(1+x)$ and $...
# 1  cn_k12  In $\triangle ABC$, the lengths of the sides o...
# 2  cn_k12  Given that $P$ is any point on the circle $C$:...
# 3  cn_k12         Factorize: $x^{3}-6x^{2}+9x=\_\_\_\_\_\_.$
# 4  cn_k12  Given that the sum of the first $n$ terms of a...
#
#                                             solution  \
# 0  1. Since $f(x) = \log_a(1+x)$ and $g(x) = \log...
# 1  Since $\cos \frac{C}{2} = \frac{\sqrt{5}}{3}$,...
# 2  The distance $d$ between the center of the cir...
# 3  To factorize the given expression $x^{3}-6x^{2...
# 4  Since $S\_n=2^{n}a\_n-1$,\nwe have $S_{n-1}=2^...
#
#                                             messages    set  index  \
# 0  [{'content': 'Given the functions $f(x) = \\lo...  train      0
# 1  [{'content': 'In $\\triangle ABC$, the lengths...  train      1
# 2  [{'content': 'Given that $P$ is any point on t...  train      2
# 3  [{'content': 'Factorize: $x^{3}-6x^{2}+9x=\\_\...  train      3
# 4  [{'content': 'Given that the sum of the first ...  train      4
#
#                                         bad_solution  \
# 0  Step 1: We observe that the given expression i...
# 1  Step 1: Using the cosine formula, we can write...
# 2  Step 1: Consider the given circle $C$ with cen...
# 3  Step 1: Finding the domain\nThe domain of $f(x...
# 4  Step 1: We first find the recursive formula fo...
#
#                      bad_solution_verification_trace  \
# 0  The candidate solution appears to be incorrect...
# 1  The candidate solution appears to be incorrect...
# 2  The solution's Step 3 is incorrect. In this st...
# 3  The candidate solution appears to be correct a...
# 4  The candidate solution appears to be incorrect...
#
#                     bad_solution_verification_prefix
# 0  Step 1: We observe that the given expression i...
# 1  Step 1: Using the cosine formula, we can write...
# 2  Step 1: Consider the given circle $C$ with cen...
# 3  Step 1: Finding the domain\nThe domain of $f(x...
# 4  Step 1: We first find the recursive formula fo...

# %%
df_audit = pd.read_csv("datasets/cn_k12_math_problems_weak_audits_5.csv")
df_audit.head()
# df_audit["candidate_solution"].iloc[0]

# print(f"Attempts count: {len(df_audit.iloc[1].attempts)}")
# print(f"Attempts: {df_audit.iloc[1].attempts}")
# print(f"Solution: {df.iloc[1].solution}")
# print(f"Candidate Solution: {df_audit.iloc[1].candidate_solution}")

# import ast

# def get_attempts(audit):
#     return ast.literal_eval(audit)

# get_attempts(df_audit.iloc[1].attempts)
# Out:
#    index                                            problem  \
# 0      0  Given the functions $f(x) = \log_a(1+x)$ and $...
# 1      1  In $\triangle ABC$, the lengths of the sides o...
# 2      2  Given that $P$ is any point on the circle $C$:...
# 3      3         Factorize: $x^{3}-6x^{2}+9x=\_\_\_\_\_\_.$
# 4      4  Given that the sum of the first $n$ terms of a...
#
#                                             solution attempts  \
# 0  1. Since $f(x) = \log_a(1+x)$ and $g(x) = \log...       []
# 1  Since $\cos \frac{C}{2} = \frac{\sqrt{5}}{3}$,...       []
# 2  The distance $d$ between the center of the cir...       []
# 3  To factorize the given expression $x^{3}-6x^{2...       []
# 4  Since $S\_n=2^{n}a\_n-1$,\nwe have $S_{n-1}=2^...       []
#
#   attempts_verification_traces  \
# 0                           []
# 1                           []
# 2                           []
# 3                           []
# 4                           []
#
#                                   candidate_solution  \
# 0  Step 1: Finding the domain\nThe domain of $f(x...
# 1  Step 1: Using the cosine formula, we can write...
# 2  Step 1: Consider the given circle $C$ with cen...
# 3  Step 1: We observe that the given expression i...
# 4  Step 1: We first find the recursive formula fo...
#
#                candidate_solution_verification_trace  \
# 0  The candidate solution appears to be correct a...
# 1  The candidate solution appears to be incorrect...
# 2  The solution's Step 3 is incorrect. In this st...
# 3  The candidate solution appears to be incorrect...
# 4  The candidate solution appears to be incorrect...
#
#               candidate_solution_verification_prefix
# 0  Step 1: Finding the domain\nThe domain of $f(x...
# 1  Step 1: Using the cosine formula, we can write...
# 2  Step 1: Consider the given circle $C$ with cen...
# 3  Step 1: We observe that the given expression i...
# 4  Step 1: We first find the recursive formula fo...
