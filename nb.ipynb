# %%
import pandas as pd

# %%
source_df = pd.read_csv("datasets/cn_k12_math_problems.csv", nrows=500)

source_df.head(2)
# Out:
#    source                                            problem  \
# 0  cn_k12  Given the functions $f(x) = \log_a(1+x)$ and $...
# 1  cn_k12  In $\triangle ABC$, the lengths of the sides o...
#
#                                             solution  \
# 0  1. Since $f(x) = \log_a(1+x)$ and $g(x) = \log...
# 1  Since $\cos \frac{C}{2} = \frac{\sqrt{5}}{3}$,...
#
#                                             messages    set  index
# 0  [{'content': 'Given the functions $f(x) = \\lo...  train      0
# 1  [{'content': 'In $\\triangle ABC$, the lengths...  train      1

# %% [markdown]
# # Result examination

# %%
df = pd.read_csv("datasets/cn_k12_math_problems_weak_solutions_3.csv")
df.head()
# Out:
#    source                                            problem  \
# 0  cn_k12  Given the functions $f(x) = \log_a(1+x)$ and $...
# 1  cn_k12  In $\triangle ABC$, the lengths of the sides o...
# 2  cn_k12  Given that $P$ is any point on the circle $C$:...
#
#                                             solution  \
# 0  1. Since $f(x) = \log_a(1+x)$ and $g(x) = \log...
# 1  Since $\cos \frac{C}{2} = \frac{\sqrt{5}}{3}$,...
# 2  The distance $d$ between the center of the cir...
#
#                                             messages    set  index  \
# 0  [{'content': 'Given the functions $f(x) = \\lo...  train      0
# 1  [{'content': 'In $\\triangle ABC$, the lengths...  train      1
# 2  [{'content': 'Given that $P$ is any point on t...  train      2
#
#                                         bad_solution
# 0  Step 1: Using the cosine law, we can write $a ...
# 1  Let's first find the equation of the circle:\n...
# 2  <answer>-1/4</answer>\n\nStep 1: Let's start b...

# %%
df_audit = pd.read_csv("datasets/cn_k12_math_problems_weak_audits_3.csv")
df_audit.head()

# print(f"Attempts count: {len(df_audit.iloc[1].attempts)}")
# print(f"Attempts: {df_audit.iloc[1].attempts}")
# print(f"Solution: {df.iloc[1].solution}")
# print(f"Candidate Solution: {df_audit.iloc[1].candidate_solution}")

# import ast

# def get_attempts(audit):
#     return ast.literal_eval(audit)

# get_attempts(df_audit.iloc[1].attempts)
# Out:
#                                              problem  \
# 0  In $\triangle ABC$, the lengths of the sides o...
# 1  Given that $P$ is any point on the circle $C$:...
# 2  Given the functions $f(x) = \log_a(1+x)$ and $...
#
#                                             solution  \
# 0  Since $\cos \frac{C}{2} = \frac{\sqrt{5}}{3}$,...
# 1  The distance $d$ between the center of the cir...
# 2  1. Since $f(x) = \log_a(1+x)$ and $g(x) = \log...
#
#                                             attempts  \
# 0  ['Step 1: Using the cosine law, we can write $...
# 1  ["Let's first find the equation of the circle:...
# 2  ["<answer>-1/4</answer>\n\nStep 1: Let's start...
#
#                                   candidate_solution
# 0  Step 1: Using the cosine law, we can write $a ...
# 1  Let's first find the equation of the circle:\n...
# 2  <answer>-1/4</answer>\n\nStep 1: Let's start b...
